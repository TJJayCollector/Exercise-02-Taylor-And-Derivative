# %% [markdown]
# <a href="https://colab.research.google.com/github/TJJayCollector/Exercise-02-Taylor-And-Derivative/blob/master/a2_1datasci.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
url='https://raw.githubusercontent.com/Phorutai/deposited_csv_data/main/hla_binding_score.csv'
df=pd.read_csv(url)
df
# Out:
#         H2-IAb    H2-IAd  HLA-DPB1_0201  HLA-DQB1_0302  HLA-DQB1_0602   \
# 0     0.627720  0.557334       0.385986       0.348487        0.760014
# 1     0.487442  0.720699       0.218867       0.289920        0.304927
# 2     0.260953  0.704893       0.786800       0.383223        0.550932
# 3     0.267792  0.444781       0.571106       0.341828        0.619531
# 4     0.629617  0.340476       0.242701       0.340104        0.605304
# ...        ...       ...            ...            ...             ...
# 3676       NaN       NaN            NaN            NaN             NaN
# 3677       NaN       NaN            NaN            NaN             NaN
# 3678       NaN       NaN            NaN            NaN             NaN
# 3679       NaN       NaN            NaN            NaN             NaN
# 3680       NaN       NaN            NaN            NaN             NaN
#
#       HLA-DRB1_0101  HLA-DRB1_0301  HLA-DRB1_0401  HLA-DRB1_0404  \
# ...

# %%
# # Create a side-by-side box plot
# plt.figure(figsize=(8, 10))  # Adjust the figure size as needed

# # Plot the binding scores for each HLA type vertically
# plt.boxplot(df.iloc[:, 1:], vert=True)

# # Customize the plot
# plt.xlabel("Binding Score")
# plt.ylabel("HLA Type")
# plt.title("Side by side box plot")

# # Show the plot
# plt.tight_layout()
# plt.show()
# for column in df:
#     plt.figure()
#     df.boxplot([column])

#df.plot(kind='box')

# Create a figure and axis
fig, ax = plt.subplots(figsize=(30, 5))

# Plot the binding scores for each HLA type
df.iloc[:, 1:].boxplot(vert=True, ax=ax,widths=0.1)

# Customize the plot
#plt.xlabel("Binding Score")
#plt.ylabel("HLA Type")
plt.title("Side by side box plot")

# Show the plot
plt.subplots_adjust(wspace=2)
plt.tight_layout()
plt.show()

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=(15, 6))

# Plot the binding scores for each HLA type vertically with narrower boxes
bp = df.iloc[:, 1:].boxplot(vert=True, ax=ax, widths=0.2)  # Adjust the width as needed

# Customize the plot
plt.title("Distribution and Median of Binding Scores for 20 HLA Types")
plt.xlabel("HLA Type")
plt.ylabel("Binding Score")

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha="right")

# Show the plot
plt.tight_layout()
plt.show()
